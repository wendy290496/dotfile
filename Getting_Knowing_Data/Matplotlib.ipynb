# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.available
plt.style.use('seaborn-v0_8-notebook')

# %%
plt.plot();

# %%
x = [1,2,3, 4]
y = [10,8,-5,9]
plt.plot(x, y, color = "red")

# %%
x = np.linspace(0,10,1000)
plt.plot(x, np.sin(x), linestyle="dashed", label='sin(x)');
plt.plot(x, np.cos(x), color='red', label = 'cos(x)')

plt.title('Sin(x) and Cos(x)')
plt.xlabel("X");
plt.ylabel("F(X)");
#plt.xlim([0,4])
#plt.ylim([-0.75, 0.6])
#plt.axis([0,4,-0.7,0.6])
#plt.axis('tight')
plt.axis('equal')

plt.legend();

# %%
#OO API
x = [1,2,3,4]
y = [11,12,13,14]
fig, ax = plt.subplots(figsize=(5,5)) #figsize = Width of height of the plot
ax.plot(x,y);
ax.set(title="A simple plot", 
       xlabel="x-axis",
       ylabel="y-axis");

# %%
#Line
x = np.linspace(0,10,100)
x[:5]
#su dung OO API

fig, ax = plt.subplots()
ax.plot(x, x**3);

# %%
#Scatter

#su dung Pyplot API
plt.scatter(x, np.exp(x));

#OO API
rng = np.random.RandomState(0)

x = rng.randn(100)
y = rng.randn(100)

colors = rng.random(100)
sizes = 1000*rng.rand(100)

fig, ax = plt.subplots()
img2 = ax.scatter(x,y,s=sizes,c=colors,cmap='viridis',alpha=0.3);
fig.colorbar(img2);

# %%
#Bar
soft_drink_prices = {"Coke": 10,
                     "Pessi": 18,
                     "Sprite": 9}
fig, ax = plt.subplots()
ax.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax.set(title="Bach Hoa Xanh's Prices",ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(soft_drink_prices.keys()), list(soft_drink_prices.values()));

# %%
#Histogram
np.random.seed(42)
student_height = np.random.normal(170,10, 250)
student_height[:10], len(student_height)
# Out:
# (array([174.96714153, 168.61735699, 176.47688538, 185.23029856,
#         167.65846625, 167.65863043, 185.79212816, 177.67434729,
#         165.30525614, 175.42560044]),
#  250)

# %%
plt.hist(student_height, bins=30);

# %%
#Subplots
#option 1: OO API
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

ax1.plot(x, x/2);
ax1.plot(x, x*2);

ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax4.hist(student_height, bins=30);

# %%
#option 2

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x, x/2);
ax[0,0].plot(x, x*2);

ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(soft_drink_prices.keys(), soft_drink_prices.values());
ax[1,1].hist(student_height, bins=30);

# %% [markdown]
# ## Project: Data Visualization - California Cities

# %%
import numpy as nd
import pandas as pd
import matplotlib.pyplot as plt

# %%
cities = pd.read_csv('./california_cities.csv')
cities.head()
cities['area_total_km2'].sort_values(ascending=False)
# Out:
# 239    1302.000
# 367     964.510
# 55      527.401
# 375     466.109
# 26      371.946
#          ...
# 163         NaN
# 237         NaN
# 370         NaN
# 393         NaN
# 443         NaN
# Name: area_total_km2, Length: 482, dtype: float64

# %%
#Extract latd and longd

lat, long = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']
plt.figure(figsize=(8,6))

#Plot using Pyplot API
plt.scatter(long, lat, 
            c=np.log10(population), 
            cmap='viridis', 
            s=area,linewidths=0, alpha=0.5);
plt.axis('equal');
plt.xlabel('Longtitude');
plt.ylabel('Latitude');
plt.colorbar(label='log$_{10}$(population)');
plt.clim(3,7);
plt.title("California cities: Population and Area Distribution");

#create a legend for cities's area
area_range=[50,100,300,500]
for area in area_range:
    plt.scatter([],[],s=area,c='k', alpha=0.4,
                label=str(area) + 'km$^2$')
plt.legend(scatterpoints=1, labelspacing=1,title='City Area');
